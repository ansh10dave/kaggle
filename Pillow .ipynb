# %%
import numpy as np 
import matplotlib.pyplot as plt 
from PIL import Image

# %%
my_image = "Downloads/messi2.jpg"

# %%
image = Image.open(my_image) 
type(image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
image.show()

# %%
plt.figure(figsize=(10,10)) 
plt.imshow(image)
plt.show()

# %%
image.size
# Out:
# (1001, 563)

# %%
image.mode
# Out:
# 'RGB'

# %%
im = image.load() ## Pixel Access

# %%
im[1,0]
# Out:
# (3, 2, 7)

# %%
from PIL import ImageOps

# %%
img_gray = ImageOps.grayscale(image) 
img_gray
# Out:
# <PIL.Image.Image image mode=L size=1001x563>

# %%
img_gray.mode
# Out:
# 'L'

# %%
img_gray.quantize(256 // 128)
# Out:
# <PIL.Image.Image image mode=P size=1001x563>

# %%
red, green, blue = image.split()

# %%
red.show()

# %%
img = np.array(image)

# %%
print(img.min())
print(img.max())
# Out:
# 0
# 255

# %%
plt.figure(figsize=(10,10)) 
plt.imshow(img)
plt.show()

# %%
plt.figure(figsize=(10,10)) 
plt.imshow(img[:200, :, :])

# %%
img[:,:,0] = 0
plt.imshow(img)
