# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('India_Menu.csv')

# %%
df
# Out:
#        Menu Category              Menu Items Per Serve Size  Energy (kCal)  \
# 0       Regular Menu        McVeggie™ Burger          168 g         402.05
# 1       Regular Menu    McAloo Tikki Burger®          146 g         339.52
# 2       Regular Menu  McSpicy™ Paneer Burger          199 g         652.76
# 3       Regular Menu       Spicy Paneer Wrap          250 g         674.68
# 4       Regular Menu     American Veg Burger          177 g         512.17
# ..               ...                     ...            ...            ...
# 136  Condiments Menu  Tomato Ketchup Sachets            8 g          11.23
# 137  Condiments Menu             Maple Syrup           30 g          86.40
# 138  Condiments Menu            Cheese Slice           14 g          51.03
# 139  Condiments Menu              Sweet Corn           40 g          45.08
# 140  Condiments Menu    Mixed Fruit Beverage         180 ml          72.25
#
#      Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  \
# ...

# %%
df['Menu Category'].value_counts()
# Out:
# McCafe Menu        51
# Regular Menu       36
# Beverages Menu     17
# Breakfast Menu     15
# Gourmet Menu       11
# Condiments Menu     9
# Desserts Menu       2
# Name: Menu Category, dtype: int64

# %%
grp = df.groupby('Menu Category')['Menu Items']

# %%
grp.describe()
# Out:
#                 count unique                             top freq
# Menu Category
# Beverages Menu     17     17                 Small Coca-Cola    1
# Breakfast Menu     15     15                    Veg McMuffin    1
# Condiments Menu     9      9            Mustard diping sauce    1
# Desserts Menu       2      2           Small McFlurry - Oreo    1
# Gourmet Menu       11     11  American Triple Cheese Chicken    1
# McCafe Menu        51     51                  Cappuccino (L)    1
# Regular Menu       36     36                McVeggie™ Burger    1

# %%
df['Per Serve Size']
# Out:
# 0        168
# 1        146
# 2        199
# 3        250
# 4        177
#         ...
# 136        8
# 137       30
# 138       14
# 139       40
# 140    180 ml
# Name: Per Serve Size, Length: 141, dtype: object

# %%
df['Per Serve Size'] = df['Per Serve Size'].str.replace('g', '')

# %%
df['Per Serve Size'] = df['Per Serve Size'].str.replace('ml', '')

# %%
df['Per Serve Size'].astype(float)
# Out:
# 0      168.0
# 1      146.0
# 2      199.0
# 3      250.0
# 4      177.0
#        ...
# 136      8.0
# 137     30.0
# 138     14.0
# 139     40.0
# 140    180.0
# Name: Per Serve Size, Length: 141, dtype: float64

# %%
# Out:
# 0      168
# 1      146
# 2      199
# 3      250
# 4      177
#        ...
# 136      8
# 137     30
# 138     14
# 139     40
# 140    180
# Name: Per Serve Size, Length: 141, dtype: object
